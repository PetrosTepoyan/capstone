# %%
import pandas as pd

# %%
df = pd.read_csv("../scraping_results/scraping_log.csv")
df = df.drop_duplicates(subset = ["webpage", "success"])
df
# Out:
#       Unnamed: 0    source                                            webpage  \
# 0              0      bars  https://bars.am/en/properties/standard/apartme...
# 1              1  myrealty  https://myrealty.am/en/3-bedroom/apartment-for...
# 2              2      bars  https://bars.am/en/properties/standard/apartme...
# 3              3  myrealty  https://myrealty.am/en/2-bedroom/apartment-for...
# 4              4      bars  https://bars.am/en/properties/standard/apartme...
# ...          ...       ...                                                ...
# 1192        1192      bars  https://bars.am/en/properties/standard/apartme...
# 1193        1193      bars  https://bars.am/en/properties/standard/apartme...
# 1194        1194      bars  https://bars.am/en/properties/standard/apartme...
# 1195        1195      bars  https://bars.am/en/properties/standard/apartme...
# 1196        1196      bars  https://bars.am/en/properties/standard/apartme...
#
#       success error
# ...

# %%
df.to_csv("../scraping_results/scraping_log.csv")
