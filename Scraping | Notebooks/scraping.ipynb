# %%
# %load_ext autoreload
# %autoreload 2

import sys
import logging
from logging import Logger
sys.path.append("..")

# %%
logging.basicConfig(filename = 'scraping.log', level = logging.INFO)
logger = logging.getLogger("main")
logger.info("This is a test message")

# %% [markdown]
# # MyRealty

# %%
# MyRealty
from ConcreteScrapers.MyRealty.MyRealtyScrapingPipeline import MyRealtyScrapingPipeline

# Storage
from ConcreteStorages import CSVStorage

# Services
from Services import ImageLoader

storage = CSVStorage(
    file_path = "../data/myrealty_apartments.csv",
    images_path = "../images/",
    logger = logger
)
storage.initialize()

image_loader = ImageLoader(
    storage,
    logger = logger
)

my_realty_scraper_pipeline = MyRealtyScrapingPipeline(
    "https://myrealty.am/en/apartments-for-sale/7784", 
    storage,
    image_loader = image_loader,
    logger = logger
)

links = my_realty_scraper_pipeline.get_apartment_links()
for link in links:
    my_realty_scraper_pipeline.scrape_apartment(link)
    print("Scraped", link)
    
my_realty_scraper_pipeline.navigate_to_next_page()
print("Navigated to next page")

links = my_realty_scraper_pipeline.get_apartment_links()
for link in links:
    my_realty_scraper_pipeline.scrape_apartment(link)
    print("Scraped", link)
storage.close_file()
# Out:
# Creating the directory: ../data
# Creating the file: ../data/myrealty_apartments.csv
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Shiraz+St/Achapnyak/Yerevan/142336
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale-in-new-construction/Sebastia+str/Malatia-Sebastia/Yerevan/142335
# Scraped https://myrealty.am/en/4-bedroom/apartment-for-sale-in-new-construction/Armenak+Armenakyan+St/Norq+Marash/Yerevan/142334
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Nersisyan+St/Qanaqer-Zeytun/Yerevan/142333
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale-in-new-construction/Davtashen+4+district/Davtashen/Yerevan/142332
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Myasnikyan+Ave/Center/Yerevan/142331
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/G.+Hovsepyan+St/Norq+Marash/Yerevan/142329
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Mher+Mkrtchyan+St/Center/Yerevan/142328
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Sevak+St/Qanaqer-Zeytun/Yerevan/142326
# Scraped https://myrealty.am/en/4-bedroom/apartment-for-sale/Pushkin+St/Center/Yerevan/142323
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Saryan+St/Center/Yerevan/142320
# Scraped https://myrealty.am/en/4-bedroom/apartment-for-sale/Antarayin+St/Center/Yerevan/142313
# Scraped https://myrealty.am/en/6-bedroom/apartment-for-sale/Mashtots+Ave/Center/Yerevan/142312
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale-in-new-construction/Charents+St/Center/Yerevan/142307
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Charents+St/Center/Yerevan/142306
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Nor+Aresh+42+St/Erebuni/Yerevan/142304
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/N.+Tigranyan+St/Arabkir/Yerevan/142301
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Sebastia+str/Malatia-Sebastia/Yerevan/142300
# Scraped https://myrealty.am/en/4-bedroom/apartment-for-sale-in-new-construction/Sebastia+str/Malatia-Sebastia/Yerevan/142299
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale/Mashtots+Ave/Center/Yerevan/142296
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Mikoyan+St/Davtashen/Yerevan/142294
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Ghazar+Parpetsi+St/Center/Yerevan/142292
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/A.+Khachatrian+St/Arabkir/Yerevan/142291
# Scraped https://myrealty.am/en/4-bedroom/apartment-for-sale/Saryan+St/Center/Yerevan/142290
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale-in-new-construction/Leo+St/Center/Yerevan/142288
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Tigran+Petrosyan+St/Davtashen/Yerevan/142285
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Lvovyan+St/Nor+Norq/Yerevan/142283
# Scraped https://myrealty.am/en/4-bedroom/apartment-for-sale/Arshakunyats+Ave/Center/Yerevan/142282
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale/Nikol+Duman+St/Arabkir/Yerevan/142280
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale-in-new-construction/Raffi+St/Malatia-Sebastia/Yerevan/142279
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Rostom+St/Center/Yerevan/142274
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Mikoyan+St/Davtashen/Yerevan/142272
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale-in-new-construction/Vardanants+St/Center/Yerevan/142267
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale-in-new-construction/Mikoyan+St/Davtashen/Yerevan/142266
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Davit+Anhaxt+St/Qanaqer-Zeytun/Yerevan/142262
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Adonts+St/Arabkir/Yerevan/142260
# Navigated to next page
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale-in-new-construction/Mikoyan+St/Davtashen/Yerevan/142259
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale-in-new-construction/Leningradyan+St/Achapnyak/Yerevan/142258
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/A.+Tigranyan+St/Qanaqer-Zeytun/Yerevan/142239
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale-in-new-construction/Tsitsernakaberd+Highway/Center/Yerevan/142238
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/M.Khorenatsi+St/Center/Yerevan/142231
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Tigran+Mets+Ave/Center/Yerevan/142228
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Khaghagh+Don+St/Erebuni/Yerevan/142224
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Gusan+Sheram+St/Malatia-Sebastia/Yerevan/142221
# Scraped https://myrealty.am/en/1-bedroom/apartment-for-sale/N.+Tigranyan+St/Arabkir/Yerevan/142209
# Scraped https://myrealty.am/en/4-bedroom/apartment-for-sale/Leo+St/Center/Yerevan/142207
# Scraped https://myrealty.am/en/4-bedroom/apartment-for-sale-in-new-construction/NarDos+St/Center/Yerevan/142206
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Davtashen+4+St/Davtashen/Yerevan/142204
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Artashisyan+St/Shengavit/Yerevan/142202
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Tigran+Mets+Ave/Center/Yerevan/142200
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Buzand+St/Center/Yerevan/142198
# Scraped https://myrealty.am/en/5-bedroom/apartment-for-sale/Ayas+St/Center/Yerevan/142196
# Scraped https://myrealty.am/en/1-bedroom/apartment-for-sale/Abovyan+St/Center/Yerevan/142189
# Scraped https://myrealty.am/en/4-bedroom/apartment-for-sale/Saryan+St/Center/Yerevan/142180
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Hovhannisyan+distrct/Avan/Yerevan/142179
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Saryan+St/Center/Yerevan/142163
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Tigran+Petrosyan+St/Davtashen/Yerevan/142160
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/A.Manukyan+St/Center/Yerevan/142152
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Avan+4+St/Avan/Yerevan/142141
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Tumanyan+St/Center/Yerevan/142137
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Mashtots+Ave/Center/Yerevan/142134
# Scraped https://myrealty.am/en/4-bedroom/apartment-for-sale/Mashtots+Ave/Center/Yerevan/142133
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale/Komitas+Ave/Arabkir/Yerevan/142132
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Komitas+Ave/Arabkir/Yerevan/142129
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale/Hr.Kochar+St/Arabkir/Yerevan/142125
# Scraped https://myrealty.am/en/1-bedroom/apartment-for-sale-in-new-construction/Argishti+St/Center/Yerevan/142124
# Scraped https://myrealty.am/en/4-bedroom/apartment-for-sale/Abovyan+St/Center/Yerevan/142117
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Gyulbenkyan+St/Arabkir/Yerevan/142112
# Scraped https://myrealty.am/en/2-bedroom/apartment-for-sale/Orbeli+Yeghbayrner+++St/Arabkir/Yerevan/142110
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale/Aygedzor+St/Arabkir/Yerevan/142109
# Scraped https://myrealty.am/en/3-bedroom/apartment-for-sale-in-new-construction/Buzand+St/Center/Yerevan/142108
# Scraped https://myrealty.am/en/4-bedroom/apartment-for-sale/Komitas+Ave/Arabkir/Yerevan/142090

# %% [markdown]
# # Bars

# %%
# Bars
from ConcreteScrapers.Bars.BarsApartmentScrapingPipeline import BarsApartmentScrapingPipeline

# Storage
from ConcreteStorages import CSVStorage

# Services
from Services import ImageLoader

storage = CSVStorage(
    file_path = "../data/bars_apartments.csv",
    images_path = "../images/",
    logger = logger
)
storage.initialize()

image_loader = ImageLoader(
    storage,
    logger = logger
)

bars_scraper_pipeline = BarsApartmentScrapingPipeline(
    "https://bars.am/en/properties/standard/apartment", 
    storage,
    image_loader,
    logger = logger
)

links = bars_scraper_pipeline.get_apartment_links()
for link in links:
    bars_scraper_pipeline.scrape_apartment(link)
    print("Scraped", link)

bars_scraper_pipeline.navigate_to_next_page()
print("Navigated to next page")

links = bars_scraper_pipeline.get_apartment_links()
for link in links:
    bars_scraper_pipeline.scrape_apartment(link)
    print("Scraped", link)
# Out:
# Creating the file: ../data/bars_apartments.csv
# Scraped https://bars.am/en/properties/standard/apartment/1-2-990
# Scraped https://bars.am/en/properties/standard/apartment/4-3-1181
# Scraped https://bars.am/en/properties/standard/apartment/1-3-1912
# Scraped https://bars.am/en/properties/standard/apartment/1-3-2133
# Scraped https://bars.am/en/properties/standard/apartment/6-NM3-6
# Scraped https://bars.am/en/properties/standard/apartment/1-3-2132
# Scraped https://bars.am/en/properties/standard/apartment/1-N-430
# Scraped https://bars.am/en/properties/standard/apartment/6-ACH3-126
# Scraped https://bars.am/en/properties/standard/apartment/4-3-1429
# Scraped https://bars.am/en/properties/standard/apartment/4-3-1427
# Scraped https://bars.am/en/properties/standard/apartment/4-2-203
# Scraped https://bars.am/en/properties/standard/apartment/6-NM2-5
# Scraped https://bars.am/en/properties/standard/apartment/6-D3-208
# Scraped https://bars.am/en/properties/standard/apartment/2-2-281
# Scraped https://bars.am/en/properties/standard/apartment/6-D3-207
# Scraped https://bars.am/en/properties/standard/apartment/4-3-111
# Scraped https://bars.am/en/properties/standard/apartment/4-3-93
# Scraped https://bars.am/en/properties/standard/apartment/4-3-23
# Scraped https://bars.am/en/properties/standard/apartment/4-2-151
# Scraped https://bars.am/en/properties/standard/apartment/4-1-27
# Scraped https://bars.am/en/properties/standard/apartment/4-3-1426
# Scraped https://bars.am/en/properties/standard/apartment/4-3-1428
# Scraped https://bars.am/en/properties/standard/apartment/1-N-429
# Scraped https://bars.am/en/properties/standard/apartment/1-N-428
# Navigated to next page
# Scraped https://bars.am/en/properties/standard/apartment/4-3-1396
# Scraped https://bars.am/en/properties/standard/apartment/1-3-2131
# Scraped https://bars.am/en/properties/standard/apartment/1-3-1838
# Scraped https://bars.am/en/properties/standard/apartment/4-2-205
# Scraped https://bars.am/en/properties/standard/apartment/4-3-1424
# Scraped https://bars.am/en/properties/standard/apartment/4-3-1423
# Scraped https://bars.am/en/properties/standard/apartment/4-3-1421
# Scraped https://bars.am/en/properties/standard/apartment/4-3-1420
# Scraped https://bars.am/en/properties/standard/apartment/4-2-157
# Scraped https://bars.am/en/properties/standard/apartment/4-2-204
# Scraped https://bars.am/en/properties/standard/apartment/4-3-1412
# Scraped https://bars.am/en/properties/standard/apartment/6-Sh2-50
# Scraped https://bars.am/en/properties/standard/apartment/1-B-128
# Scraped https://bars.am/en/properties/standard/apartment/4-2-201
# Scraped https://bars.am/en/properties/standard/apartment/1-DH-10
# Scraped https://bars.am/en/properties/standard/apartment/1-DH-11
# Scraped https://bars.am/en/properties/standard/apartment/1-DH-12
# Scraped https://bars.am/en/properties/standard/apartment/1-DH-21
# Scraped https://bars.am/en/properties/standard/apartment/1-DH-20
# Scraped https://bars.am/en/properties/standard/apartment/1-DH-25
# Scraped https://bars.am/en/properties/standard/apartment/1-DH-8
# Scraped https://bars.am/en/properties/standard/apartment/1-DH-27
# Scraped https://bars.am/en/properties/standard/apartment/1-DH-15
# Scraped https://bars.am/en/properties/standard/apartment/1-DH-22

# %% [markdown]
# # Bnakaran

# %%
# Bnakaran
from ConcreteScrapers.Bnakaran.BnakaranScrapingPipeline import BnakaranScrapingPipeline

# Storage
from ConcreteStorages import CSVStorage

# Services
from Services import ImageLoader

storage = CSVStorage(
    file_path = "../data/bnakaran_apartments.csv",
    images_path = "../images/",
    logger = logger
)
storage.initialize()

image_loader = ImageLoader(
    storage,
    logger = logger
)

bnakaran_scraper_pipeline = BnakaranScrapingPipeline(
    "https://www.bnakaran.com/en/listing?ctype=apartment&deal=sale&country=am&sort=relevance", 
    storage,
    image_loader,
    logger = logger
)

links = bnakaran_scraper_pipeline.get_apartment_links()
for link in links:
    bnakaran_scraper_pipeline.scrape_apartment(link)
    print("Scraped", link)

bnakaran_scraper_pipeline.navigate_to_next_page()
print("Navigated to next page")

links = bnakaran_scraper_pipeline.get_apartment_links()
for link in links:
    bnakaran_scraper_pipeline.scrape_apartment(link)
    print("Scraped", link)
# Out:
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d113304
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-arabkir-yerevan-d115472
# Scraped https://www.bnakaran.com/en/duplex-for-sale-in-downtown-yerevan-d83074
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-center-yerevan-d107448
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-kanaker-zeytun-yerevan-d111383
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-davtashen-yerevan-d116753
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-ajapnyak-yerevan-d117805
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-center-yerevan-d115790
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-avan-yerevan-d116739
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-center-yerevan-d116423
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-malatia-sebastia-yerevan-d117251
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d115650
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-center-yerevan-d107965
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-arabkir-yerevan-d80872
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d85484
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-arabkir-yerevan-d116524
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-arabkir-yerevan-d111336
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d114712
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-arabkir-yerevan-d116333
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-arabkir-yerevan-d91225
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d117806
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d114612
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-arabkir-yerevan-d117205
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-downtown-yerevan-d113543
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-avan-yerevan-d108980
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-center-yerevan-d117682
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-downtown-yerevan-d117802
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d109621
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-arabkir-yerevan-d85024
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-arabkir-yerevan-d88473
# Navigated to next page
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d113304
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-arabkir-yerevan-d115472
# Scraped https://www.bnakaran.com/en/duplex-for-sale-in-downtown-yerevan-d83074
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-center-yerevan-d107448
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-kanaker-zeytun-yerevan-d111383
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-davtashen-yerevan-d116753
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-ajapnyak-yerevan-d117805
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-center-yerevan-d115790
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-avan-yerevan-d116739
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-center-yerevan-d116423
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-malatia-sebastia-yerevan-d117251
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d115650
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-center-yerevan-d107965
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-arabkir-yerevan-d80872
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d85484
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-arabkir-yerevan-d116524
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-arabkir-yerevan-d111336
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d114712
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-arabkir-yerevan-d116333
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-arabkir-yerevan-d91225
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d117806
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d114612
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-arabkir-yerevan-d117205
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-downtown-yerevan-d113543
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-avan-yerevan-d108980
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-center-yerevan-d117682
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-downtown-yerevan-d117802
# Scraped https://www.bnakaran.com/en/apartment-in-new-building-for-sale-in-downtown-yerevan-d109621
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-arabkir-yerevan-d85024
# Scraped https://www.bnakaran.com/en/apartment-for-sale-in-arabkir-yerevan-d88473

# %% [markdown]
# https://www.bnakaran.com/en/sitemap.xml
#
# https://myrealty.am/sitemap.xml
#
# Create a mapping for at least these properties:
# Balcony/Open Balcony
# Hot water -> Water availability
# try ceiling_height [low, high, unspecified]
#
# Figure out the: construction type -> building_type:
# Stone, Panel, Monolit, Other
#
# renovated as binary
#
# on failure, append the link to a stack and try at the end again

# %%
create mapping of features

# %%
from ConcreteScrapers.GlobalScrapingPipeline import GlobalScrapingPipeline
global_pipeline = GlobalScrapingPipeline([
    my_realty_scraper_pipeline,
    bars_scraper_pipeline
])
global_pipeline.run()

# %% [markdown]
# # GeoService

# %%
from Services import GeoFeaturesExtractor
geoService = GeoFeaturesExtractor(["supermarket", "restaurant", "store", "hospital", "subway_station", "school", "beauty_salon"], 1000)
lat, lng = geoService.location("Yerevan/Erebuni/Khorenatsi Street (ER.)")
amenities = geoService.find_nearby_places(f"{lat},{lng}")
print(amenities)
# Out:
# [Amenity: store, Latitude: 40.1503659, Longitude: 44.5231357, Amenity: restaurant, Latitude: 40.1416798, Longitude: 44.5222183, Amenity: school, Latitude: 40.14604459999999, Longitude: 44.5233545, Amenity: school, Latitude: 40.140908, Longitude: 44.5203911, Amenity: beauty_salon, Latitude: 40.1456645, Longitude: 44.52097089999999, Amenity: supermarket, Latitude: 40.1421264, Longitude: 44.5211657, Amenity: store, Latitude: 40.1421264, Longitude: 44.5211657, Amenity: store, Latitude: 40.1423248, Longitude: 44.5224935]
