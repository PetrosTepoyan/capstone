# %%
import torch
from tqdm import tqdm
from torch import nn, optim
from torch.nn import init
import pandas as pd
import pandas as pd
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

data = pd.read_csv("../../data2/data.csv").drop(columns = ["id", "source", 
                                                       "latitude", "longitude"])

# %%
class TabularFFNNSimple(nn.Module):
    def __init__(self, input_size, output_size, dropout_prob=0.4):
        super(TabularFFNNSimple, self).__init__()
        hidden_size = 64
        self.ffnn = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(),
#             nn.BatchNorm1d(hidden_size),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.18),
            nn.Linear(hidden_size, output_size)
        )
        
        for m in self.ffnn:
            if isinstance(m, nn.Linear):
                init.xavier_uniform_(m.weight)
                m.bias.data.fill_(0)

    def forward(self, x):
        x = x.float()
        # print(x)
        x = x.view(x.size(0), -1)
        x = self.ffnn(x)
        return x
    
# Split the data into features and target
X = data.drop('price', axis=1)
y = data['price']

# Standardize the features
device = torch.device("cpu")
# Convert to PyTorch tensors
X_tensor = torch.tensor(X.to_numpy(), dtype=torch.float32, device = device)
y_tensor = torch.tensor(y.values, dtype=torch.float32, device = device)


# Split the data into training and combined validation and testing sets
X_train, X_val_test, y_train, y_val_test = train_test_split(X_tensor, y_tensor,
                                                            test_size=0.4, random_state=42)

# Split the combined validation and testing sets
X_val, X_test, y_val, y_test = train_test_split(X_val_test, y_val_test, test_size=0.5, random_state=42)

# Create DataLoader for training, validation, and testing
train_data = TensorDataset(X_train, y_train)
val_data = TensorDataset(X_val, y_val)
test_data = TensorDataset(X_test, y_test)

batch_size = 512
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

# Check if the dimensions match the expected input size for the model
input_size = X_train.shape[1]

# Output
# input_size, train_loader, test_loader

model = TabularFFNNSimple(
    input_size = input_size,
    output_size = 1
)
model.to(device)

num_epochs = 300000
train_losses = []
val_losses = []
epochs_suc = [] # to have a reference to it
grad_norms = []

def get_gradient_norm(model):
    total_norm = 0
    for p in model.parameters():
        if p.grad is not None:
            param_norm = p.grad.data.norm(2)
            total_norm += param_norm.item() ** 2
    total_norm = total_norm ** 0.5
    return total_norm

# %%
optimizer = optim.Adam(
    model.parameters(), 
    lr=9e-3,
    weight_decay=3e-2
)
criterion = torch.nn.MSELoss()
criterion_abs = torch.nn.L1Loss()
criterion = criterion_abs

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, 
    mode='min', 
    factor=0.999999, 
    patience=5, 
    verbose=True
)

for epoch in range(num_epochs):
    # Training
    model.train()  # Set the model to training mode
    running_loss = 0.0
    l1_losses = []
    grad_norm = 0
    for tuple_ in train_loader:
        datas, prices = tuple_
        optimizer.zero_grad()
        outputs = model(datas)
        prices_viewed = prices.view(-1, 1).float()
        loss = criterion(outputs, prices_viewed)
        loss.backward()
        grad_norm += get_gradient_norm(model)
        optimizer.step()

        running_loss += loss.item()
        
    grad_norms.append(grad_norm / len(train_loader))
    train_losses.append(running_loss / len(train_loader))  # Average loss for this epoch

    # Validation
    model.eval()  # Set the model to evaluation mode
    val_loss = 0.0
    with torch.no_grad():  # Disable gradient calculation
        for tuple_ in val_loader:
            datas, prices = tuple_
            outputs = model(datas)  # Forward pass
            prices_viewed = prices.view(-1, 1).float()
            loss = criterion(outputs, prices_viewed)  # Compute loss
            val_loss += loss.item()  # Accumulate the loss
            l1_losses.append(criterion_abs(outputs, prices_viewed))

    val_losses.append(val_loss / len(val_loader))  # Average loss for this epoch
    l1_mean_loss = sum(l1_losses) / len(l1_losses)
    # Print epoch's summary
    epochs_suc.append(epoch)
    scheduler.step(val_losses[-1])
    if epoch % 100 == 0:
        tl = f"Training Loss: {int(train_losses[-1])}"
        vl = f"Validation Loss: {int(val_losses[-1])}"
        l1 = f"L1: {int(l1_mean_loss)}"
        dl = f'Epoch {epoch+1}, {tl}, {vl}, {grad_norms[-1]}'
        print(dl)
# Out:
# Epoch 1, Training Loss: 235530, Validation Loss: 219217, 14132.95922376733
# Epoch 101, Training Loss: 66762, Validation Loss: 71027, 420138.2136633163
# Epoch 201, Training Loss: 68518, Validation Loss: 67026, 967094.8435474538
# Epoch 301, Training Loss: 59671, Validation Loss: 74723, 483361.54043100495
# Epoch 401, Training Loss: 60326, Validation Loss: 58866, 481870.93732394645
# Epoch 501, Training Loss: 57090, Validation Loss: 66626, 616448.9120331354
# Epoch 601, Training Loss: 58952, Validation Loss: 71881, 791847.2635404957
# Epoch 701, Training Loss: 55667, Validation Loss: 61453, 628673.3835683124
# Epoch 801, Training Loss: 55118, Validation Loss: 79248, 880266.0464075617
# Epoch 901, Training Loss: 54826, Validation Loss: 81445, 804966.8025929957
# Epoch 1001, Training Loss: 53179, Validation Loss: 63321, 538903.216482568
# Epoch 1101, Training Loss: 50487, Validation Loss: 92376, 799649.8589320531
# Epoch 1201, Training Loss: 53332, Validation Loss: 76393, 817106.4898427514
# Epoch 1301, Training Loss: 48968, Validation Loss: 70777, 491749.8560660354
# Epoch 1401, Training Loss: 52091, Validation Loss: 63417, 634616.2594008389
# Epoch 1501, Training Loss: 46113, Validation Loss: 86915, 393763.11456486915
# Epoch 1601, Training Loss: 50006, Validation Loss: 69203, 935503.6748270108
# Epoch 1701, Training Loss: 49173, Validation Loss: 90593, 457530.3733692132
# Epoch 1801, Training Loss: 48261, Validation Loss: 71690, 771113.7848497266
# Epoch 1901, Training Loss: 46782, Validation Loss: 63709, 616423.3584737588
# Epoch 2001, Training Loss: 45877, Validation Loss: 86827, 691668.3555936121
# Epoch 2101, Training Loss: 48185, Validation Loss: 82757, 818796.8615518343
# Epoch 2201, Training Loss: 49774, Validation Loss: 81721, 888288.3536958043
# Epoch 2301, Training Loss: 48088, Validation Loss: 86334, 949730.1490371345
# Epoch 2401, Training Loss: 42596, Validation Loss: 70825, 357970.1130094189
# Epoch 2501, Training Loss: 51069, Validation Loss: 56159, 840883.8595614424
# Epoch 2601, Training Loss: 39974, Validation Loss: 62762, 467048.2669281869
# Epoch 2701, Training Loss: 42692, Validation Loss: 84567, 719221.6838990246
# Epoch 2801, Training Loss: 43403, Validation Loss: 71750, 799407.0407310552
# Epoch 2901, Training Loss: 40308, Validation Loss: 60746, 489513.2502218103
# Epoch 3001, Training Loss: 44072, Validation Loss: 63586, 1005812.864861582
# Epoch 3101, Training Loss: 44738, Validation Loss: 76041, 1028352.4259626301
# Epoch 3201, Training Loss: 38908, Validation Loss: 65608, 655820.8685094626
# Epoch 3301, Training Loss: 40760, Validation Loss: 69794, 386925.5209567067
# Epoch 3401, Training Loss: 42733, Validation Loss: 69535, 1159150.608021197
# Epoch 3501, Training Loss: 37134, Validation Loss: 72565, 376446.32258615043
# Epoch 3601, Training Loss: 38236, Validation Loss: 94431, 552786.6860789623
# Epoch 3701, Training Loss: 37352, Validation Loss: 70499, 490260.83799899026
# Epoch 3801, Training Loss: 42787, Validation Loss: 69096, 1347744.768981702
# Epoch 3901, Training Loss: 37868, Validation Loss: 67363, 419740.5623076511
# Epoch 4001, Training Loss: 41225, Validation Loss: 77026, 828343.3249060618
# Epoch 4101, Training Loss: 40731, Validation Loss: 77562, 476733.87428770115
# Epoch 4201, Training Loss: 42156, Validation Loss: 61798, 810378.0212828672
# Epoch 4301, Training Loss: 44837, Validation Loss: 64681, 1297310.895233542
# Epoch 4401, Training Loss: 37029, Validation Loss: 86808, 688991.8552285136
# Epoch 4501, Training Loss: 45336, Validation Loss: 67827, 820245.6609416179
# Epoch 4601, Training Loss: 37322, Validation Loss: 85277, 696290.0143770432
# Epoch 4701, Training Loss: 40959, Validation Loss: 61421, 740779.7882672722
# Epoch 4801, Training Loss: 38584, Validation Loss: 71648, 1120322.2807699302
# Epoch 4901, Training Loss: 36821, Validation Loss: 76266, 385470.2492854051
# Epoch 5001, Training Loss: 34103, Validation Loss: 64041, 574934.9687756379
# Epoch 5101, Training Loss: 38863, Validation Loss: 65595, 878615.7653550985
# Epoch 5201, Training Loss: 44063, Validation Loss: 90913, 1225582.3781951137
# Epoch 5301, Training Loss: 39131, Validation Loss: 68636, 853145.2756274055
# Epoch 5401, Training Loss: 38249, Validation Loss: 67378, 505412.4590136521
# Epoch 5501, Training Loss: 36873, Validation Loss: 76693, 572789.6380974369
# Epoch 5601, Training Loss: 39833, Validation Loss: 66585, 891443.3270257573
# Epoch 5701, Training Loss: 37025, Validation Loss: 78954, 429614.91370286216
# Epoch 5801, Training Loss: 43146, Validation Loss: 73183, 1319379.3118420597
# Epoch 5901, Training Loss: 37860, Validation Loss: 80046, 546932.0986884675
# Epoch 6001, Training Loss: 39341, Validation Loss: 83774, 847106.2516449088
# Epoch 6101, Training Loss: 34922, Validation Loss: 75753, 666263.5461232081
# Epoch 6201, Training Loss: 38935, Validation Loss: 70089, 982989.5157703841
# Epoch 6301, Training Loss: 37097, Validation Loss: 82675, 762779.9763249889
# Epoch 6401, Training Loss: 36501, Validation Loss: 64648, 626132.1621931625
# Epoch 6501, Training Loss: 38122, Validation Loss: 71943, 942028.4815775085
# Epoch 6601, Training Loss: 35655, Validation Loss: 79123, 580778.213286578
# Epoch 6701, Training Loss: 39763, Validation Loss: 92688, 1003753.0523974462
# Epoch 6801, Training Loss: 35311, Validation Loss: 77065, 616576.4357647336
# Epoch 6901, Training Loss: 37593, Validation Loss: 72448, 1164771.6489597738
# Epoch 7001, Training Loss: 33841, Validation Loss: 76705, 404809.51609371044
# Epoch 7101, Training Loss: 37430, Validation Loss: 63100, 755899.802306105
# Epoch 7201, Training Loss: 36062, Validation Loss: 72190, 437897.45036736195
# Epoch 7301, Training Loss: 37759, Validation Loss: 67009, 747837.9758256826
# Epoch 7401, Training Loss: 34165, Validation Loss: 79664, 368980.2151103711
# Epoch 7501, Training Loss: 32410, Validation Loss: 76091, 488744.3546124071
# Epoch 7601, Training Loss: 34601, Validation Loss: 74073, 442935.9693503535
# Epoch 7701, Training Loss: 35992, Validation Loss: 80197, 519662.5315803979
# Epoch 7801, Training Loss: 37554, Validation Loss: 70071, 462199.4000155418
# Epoch 7901, Training Loss: 34074, Validation Loss: 71051, 616033.106486936
# Epoch 8001, Training Loss: 34577, Validation Loss: 72253, 833789.0339161726
# Epoch 8101, Training Loss: 37418, Validation Loss: 66827, 807853.135649729
# Epoch 8201, Training Loss: 35142, Validation Loss: 70250, 987171.6569820866
# Epoch 8301, Training Loss: 33262, Validation Loss: 82764, 797573.9970934758
# Epoch 8401, Training Loss: 37782, Validation Loss: 76867, 823321.2511360502
# Epoch 8501, Training Loss: 39224, Validation Loss: 93577, 1012671.5009411388
# Epoch 8601, Training Loss: 28989, Validation Loss: 66967, 397311.05648396886
# Epoch 8701, Training Loss: 34456, Validation Loss: 81961, 554848.5794796442
# Epoch 8801, Training Loss: 33612, Validation Loss: 83642, 627494.965810689
# Epoch 8901, Training Loss: 36035, Validation Loss: 77760, 424236.59437412367
# Epoch 9001, Training Loss: 33066, Validation Loss: 69591, 394230.37023456494
# Epoch 9101, Training Loss: 33406, Validation Loss: 71653, 659592.4638231199
# Epoch 9201, Training Loss: 31439, Validation Loss: 63716, 490478.5068102588
# Epoch 9301, Training Loss: 33431, Validation Loss: 75478, 387806.3877640742
# Epoch 9401, Training Loss: 32493, Validation Loss: 72253, 280033.25472071534
# Epoch 9501, Training Loss: 32248, Validation Loss: 79811, 502573.62450820836
# Epoch 9601, Training Loss: 32269, Validation Loss: 69468, 538142.1715678602
# Epoch 9701, Training Loss: 32410, Validation Loss: 67072, 575674.2929414936
# Epoch 9801, Training Loss: 33673, Validation Loss: 83848, 533344.6632888115
# Epoch 9901, Training Loss: 32335, Validation Loss: 77499, 591524.5425075974
# Epoch 10001, Training Loss: 33628, Validation Loss: 71493, 901255.2095029136
# Epoch 10101, Training Loss: 34688, Validation Loss: 83070, 714541.2770813393
# Epoch 10201, Training Loss: 32213, Validation Loss: 75995, 557512.3580322674
# Epoch 10301, Training Loss: 32273, Validation Loss: 72303, 710149.3343526265
# Epoch 10401, Training Loss: 35446, Validation Loss: 83740, 723624.156555572
# Epoch 10501, Training Loss: 31045, Validation Loss: 83096, 421151.0767363414
# Epoch 10601, Training Loss: 33502, Validation Loss: 82895, 542687.174398053
# Epoch 10701, Training Loss: 31769, Validation Loss: 80339, 816767.9770434514
# Epoch 10801, Training Loss: 30931, Validation Loss: 72872, 446190.05406807456
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 18>()
#      41 val_loss = 0.0
#      42 with torch.no_grad():  # Disable gradient calculation
# ---> 43     for tuple_ in val_loader:
#      44         datas, prices = tuple_
#      45         outputs = model(datas)  # Forward pass
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataset.py:208, in TensorDataset.__getitem__(self, index)
#     207 def __getitem__(self, index):
# --> 208     return tuple(tensor[index] for tensor in self.tensors)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataset.py:208, in <genexpr>(.0)
#     207 def __getitem__(self, index):
# --> 208     return tuple(tensor[index] for tensor in self.tensors)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

train_losses_sampled = train_losses[::10000]  # Select every 1000th value
val_losses_sampled = val_losses[::10000]      # Select every 1000th value

# Generate corresponding epoch numbers, assuming epochs_suc is your list of epoch numbers
epochs_sampled = epochs_suc[::10000]

plt.style.use("ggplot")
plt.title("Overfitted model evaluation")


# Use sampled data for plotting
plt.plot(epochs_sampled, train_losses_sampled, label='Training')
plt.plot(epochs_sampled, val_losses_sampled, label='Validation')

plt.ylabel("MSE")
plt.xlabel("Epoch")
plt.yscale('log')
plt.xticks(
    range(1, epochs_sampled[-1], int(epochs_sampled[-1] / 8)),
    range(1, epochs_sampled[-1], int(epochs_sampled[-1] / 8)),
    rotation = 25
)
plt.legend()
plt.show()
# plt.savefig("../visualizations/overfit_model_evaluation_full_dataset.png", dpi=800)

# %% [markdown]
# # Saving. Good results

# %%
# class TabularFFNNSimple(nn.Module):
#     def __init__(self, input_size, output_size, dropout_prob=0.4):
#         super(TabularFFNNSimple, self).__init__()
#         hidden_size = 48
#         self.ffnn = nn.Sequential(
#             nn.Linear(input_size, hidden_size),
#             nn.ReLU(),
# #             nn.BatchNorm1d(hidden_size),
# #             nn.Dropout(0.5),
#             nn.Linear(hidden_size, hidden_size),
#             nn.ReLU(),
# #             nn.Dropout(0.5),
#             nn.Linear(hidden_size, output_size)
#         )
        
#         for m in self.ffnn:
#             if isinstance(m, nn.Linear):
#                 init.xavier_uniform_(m.weight)
#                 m.bias.data.fill_(0)

#     def forward(self, x):
#         x = x.float()
#         # print(x)
#         x = x.view(x.size(0), -1)
#         x = self.ffnn(x)
#         return x
    
# # Split the data into features and target
# X = data.drop('price', axis=1)
# y = data['price']

# # Standardize the features
# device = torch.device("cpu")
# # Convert to PyTorch tensors
# X_tensor = torch.tensor(X.to_numpy(), dtype=torch.float32, device = device)
# y_tensor = torch.tensor(y.values, dtype=torch.float32, device = device)


# # Split the data into training and combined validation and testing sets
# X_train, X_val_test, y_train, y_val_test = train_test_split(X_tensor, y_tensor,
#                                                             test_size=0.4, random_state=42)

# # Split the combined validation and testing sets
# X_val, X_test, y_val, y_test = train_test_split(X_val_test, y_val_test, test_size=0.5, random_state=42)

# # Create DataLoader for training, validation, and testing
# train_data = TensorDataset(X_train, y_train)
# val_data = TensorDataset(X_val, y_val)
# test_data = TensorDataset(X_test, y_test)

# batch_size = 256
# train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
# val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
# test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

# # Check if the dimensions match the expected input size for the model
# input_size = X_train.shape[1]

# # Output
# # input_size, train_loader, test_loader

# model = TabularFFNNSimple(
#     input_size = input_size,
#     output_size = 1
# )
# model.to(device)

# num_epochs = 300000
# train_losses = []
# val_losses = []
# epochs_suc = [] # to have a reference to it
# grad_norms = []

# def get_gradient_norm(model):
#     total_norm = 0
#     for p in model.parameters():
#         if p.grad is not None:
#             param_norm = p.grad.data.norm(2)
#             total_norm += param_norm.item() ** 2
#     total_norm = total_norm ** 0.5
#     return total_norm

# optimizer = optim.Adam(
#     model.parameters(), 
#     lr=9e-3,
#     weight_decay=1e-4
# )
# criterion = torch.nn.MSELoss()
# criterion_abs = torch.nn.L1Loss()
# criterion = criterion_abs

# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
#     optimizer, 
#     mode='min', 
#     factor=0.999999, 
#     patience=10, 
#     verbose=True
# )

# for epoch in range(num_epochs):
#     # Training
#     model.train()  # Set the model to training mode
#     running_loss = 0.0
#     l1_losses = []
#     grad_norm = 0
#     for tuple_ in train_loader:
#         datas, prices = tuple_
#         optimizer.zero_grad()
#         outputs = model(datas)
#         prices_viewed = prices.view(-1, 1).float()
#         loss = criterion(outputs, prices_viewed)
#         loss.backward()
#         grad_norm += get_gradient_norm(model)
#         optimizer.step()

#         running_loss += loss.item()
        
#     grad_norms.append(grad_norm / len(train_loader))
#     train_losses.append(running_loss / len(train_loader))  # Average loss for this epoch

#     # Validation
#     model.eval()  # Set the model to evaluation mode
#     val_loss = 0.0
#     with torch.no_grad():  # Disable gradient calculation
#         for tuple_ in val_loader:
#             datas, prices = tuple_
#             outputs = model(datas)  # Forward pass
#             prices_viewed = prices.view(-1, 1).float()
#             loss = criterion(outputs, prices_viewed)  # Compute loss
#             val_loss += loss.item()  # Accumulate the loss
#             l1_losses.append(criterion_abs(outputs, prices_viewed))

#     val_losses.append(val_loss / len(val_loader))  # Average loss for this epoch
#     l1_mean_loss = sum(l1_losses) / len(l1_losses)
#     # Print epoch's summary
#     epochs_suc.append(epoch)
#     scheduler.step(val_losses[-1])
#     if epoch % 100 == 0:
#         tl = f"Training Loss: {int(train_losses[-1])}"
#         vl = f"Validation Loss: {int(val_losses[-1])}"
#         l1 = f"L1: {int(l1_mean_loss)}"
#         dl = f'Epoch {epoch+1}, {tl}, {vl}, {grad_norms[-1]}'
#         print(dl)
