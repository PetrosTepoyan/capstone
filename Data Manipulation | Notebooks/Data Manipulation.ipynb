# %%
import ast
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.8f}'.format)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
def create_dummies(row, unique_features):
    return {element: 1 if element in row else 0 for element in unique_features}

def dummify_column(df, col_name, unique_features):
    # Check if the specified column contains lists
    if df[col_name].apply(lambda x: isinstance(x, list)).all():
        # If it contains lists, flatten the lists into separate rows
        dummies = df[col_name].apply(lambda x: create_dummies(x, unique_features)).apply(pd.Series)
    else:
        # Perform one-hot encoding (dummify) on the specified column
        dummies = pd.get_dummies(df[col_name])
        
    # Concatenate the dummies with the original DataFrame and drop the original column
    df = pd.concat([df, dummies], axis=1)
    df.drop(columns=[col_name], inplace=True)

    return df

def dummify_columns(df, cols, unique_features):
    df_copy = df
    for col in cols:
        df_copy = dummify_column(df_copy, col, unique_features)
        
    return df_copy

# %%
def feature_importance(data, y_col):
    X = data.drop(y_col, axis=1)
    y = data[y_col]
    rf = RandomForestRegressor(n_estimators=100) 
    rf.fit(X, y)
    feature_importances = pd.DataFrame({
        'feature': X.columns,
        'importance': rf.feature_importances_
    })
    feature_importances = feature_importances.sort_values(
        by = 'importance',
        ascending = False
    )
    return feature_importances

def plot_feature_importance(feature_importances):
    plt.figure(figsize=(10, 6))
    plt.barh(feature_importances['feature'], feature_importances['importance'])
    plt.xlabel('Importance')
    plt.ylabel('Feature')
    plt.title('Feature Importance')
    plt.show()

# %%
file_paths = {
    "bars" : "../data/bars_apartments.csv",
    "myrealty" : "../data/myrealty_apartments.csv",
    "bnakaran" : "../data/bnakaran_apartments.csv",
}

# %% [markdown]
# ## Bars

# %%
bars = pd.read_csv(file_paths["bars"])
bars.dropna(axis = 1, how = 'all', inplace = True)
bars['facilities'] = bars['facilities'].apply(ast.literal_eval)

bars_unique_features = set([item for sublist in bars['facilities'] for item in sublist])

bars_dummy = dummify_columns(bars, ["facilities", "building_type", "condition"], bars_unique_features)
bars_dummy = bars_dummy.drop(columns = ["source", "id", "location"], axis = 1)
bars_dummy["ceiling_height"] = bars_dummy["ceiling_height"].fillna(bars_dummy["ceiling_height"].median())
bars_dummy = bars_dummy.dropna(subset=['area'])
bars_dummy = bars_dummy.dropna(subset=['price'])
feature_importance(bars_dummy, "price")
# Out:
#                    feature  importance
# 0                     area  0.58753013
# 24           Front balcony  0.13399124
# 5           bathroom_count  0.07761060
# 18                 Parking  0.02396535
# 17              First line  0.02163848
# 6                 bedrooms  0.01580645
# 4           ceiling_height  0.01532623
# 3                  storeys  0.01449241
# 25  Transport availability  0.01421177
# 2                    floor  0.01142483
# 39            New building  0.00877716
# 11            Open balcony  0.00757615
# 23                Internet  0.00535500
# 27                Panorama  0.00494121
# 48      Without renovation  0.00473367
# 32                 Jacuzzi  0.00469855
# 20        Air conditioning  0.00468868
# 1                    rooms  0.00394024
# 35       Building security  0.00383107
# 45          Major overhaul  0.00377720
# 19                    Pool  0.00358462
# 16                Wardrobe  0.00309885
# 30               Furniture  0.00292117
# 31          Superstructure  0.00268897
# 14          Heating system  0.00248890
# 29               Fireplace  0.00232203
# 13          Closed balcony  0.00206792
# 9         Building service  0.00199391
# 33                Elevator  0.00143228
# 34         Washing machine  0.00128119
# 15                  Garage  0.00112937
# 41         Special project  0.00087238
# 36                      TV  0.00076986
# 42            Stalinka c/o  0.00070243
# 46      Old major overhaul  0.00061217
# 26      Built-in furniture  0.00056727
# 8         Exclusive design  0.00055441
# 21                 Mansard  0.00052033
# 28                  Fridge  0.00051264
# 7            Kitchen stove  0.00037829
# 44                   Stone  0.00024604
# 37       Kitchen furniture  0.00023537
# 10                 Terrace  0.00020640
# 22              Dishwasher  0.00019552
# 40                   Panel  0.00019251
# 43            Stalinka w/o  0.00009567
# 47            Redecoration  0.00001308
# 38              Monolithic  0.00000000
# 12          Cooling system  0.00000000

# %% [markdown]
# # MyRealty

# %%
myrealty = pd.read_csv(file_paths["myrealty"])
myrealty.dropna(axis=1, how='all', inplace = True)
myrealty['facilities'] = myrealty['facilities'].apply(ast.literal_eval)
myrealty['ceiling_height'] = myrealty['ceiling_height'].str.replace('[^\d.]', '', regex=True)
myrealty['ceiling_height'] = pd.to_numeric(myrealty['ceiling_height'], errors='coerce')

# %%
myrealty_unique_features = set([item for sublist in myrealty['facilities'] for item in sublist])

# %%
myrealty_dummy = dummify_columns(
    myrealty,
    ["facilities", "building_type", "condition"],
    myrealty_unique_features
)
myrealty_dummy = myrealty_dummy.drop(columns = ["source", "id", "location", "added_in_date"], axis = 1)
feature_importance(myrealty_dummy, "price")
# Out:
#                      feature  importance
# 0                       area  0.60107105
# 6                 view_count  0.05625174
# 3                    storeys  0.03668100
# 50            Newly repaired  0.01945327
# 8                 Playground  0.01767538
# 4             ceiling_height  0.01648985
# 39                Irrigation  0.01524810
# 18           Air-conditioner  0.01461600
# 5             bathroom_count  0.01445822
# 23                  Roadside  0.01400673
# 13                       Gas  0.01248853
# 1                      rooms  0.01081426
# 26  Close to the bus station  0.01016033
# 9                      Sunny  0.00947225
# 42                  Elevator  0.00925196
# 2                      floor  0.00893427
# 34         Laminate flooring  0.00846088
# 40                 Iron door  0.00836179
# 44    Sewerage, Canalization  0.00732969
# 31                     Water  0.00729332
# 20                   Parquet  0.00729118
# 35                water 24/7  0.00646657
# 25           Security system  0.00638346
# 51            Zero condition  0.00628305
# 45                   Monolit  0.00622881
# 21                  Basement  0.00584788
# 19                      Park  0.00570644
# 41                 Furniture  0.00453246
# 17              Euro windows  0.00445774
# 15                      View  0.00439828
# 36                   Heating  0.00428875
# 33                  Internet  0.00398444
# 32                 Hot water  0.00384163
# 22                 Bilateral  0.00351693
# 38                   Balcony  0.00350628
# 27                   Parking  0.00312725
# 47                     Panel  0.00301531
# 14              Open balcony  0.00287926
# 48                     Stone  0.00285845
# 16           Central heating  0.00219544
# 30                      Tile  0.00203775
# 12          High first floor  0.00190954
# 7                Electricity  0.00185199
# 10                 Equipment  0.00161142
# 43              Heated floor  0.00138760
# 49                      Good  0.00130852
# 28              Storage room  0.00024031
# 11                    Loggia  0.00011708
# 24                    Garage  0.00010611
# 29                     Sauna  0.00006770
# 46                     Other  0.00002318
# 37                 Fireplace  0.00001058

# %% [markdown]
# # Bnakaran # from room_details we can get bathrooms

# %%
bnakaran = pd.read_csv(file_paths["bnakaran"])
bnakaran.dropna(axis=1, how='all', inplace = True)
bnakaran['additional_features'] = bnakaran['additional_features'].apply(ast.literal_eval)

# %%
bnakaran_unique_features = set([item for sublist in bnakaran['additional_features'] for item in sublist])

# %%
bnakaran_dummy = dummify_columns(bnakaran, ["additional_features"], bnakaran_unique_features)
bnakaran_dummy = bnakaran_dummy.drop(
    columns = ["source", "id", "added_in_date", "room_details", "details", "utilities"], 
    axis = 1
)
bnakaran_dummy = bnakaran_dummy.dropna(subset=['price'])
bnakaran_dummy.head(1)
# Out:
#             price  area  rooms  floor  storeys    latitude  visit_count  \
# 0 300000.00000000    75      3      8       14 44.50805864           24
#
#     longitude  heating flooring  oriel  plastic windows  sec. worker  \
# 0 40.21100941                 1      0                1            0
#
#    sec. sys.  bathtub  new water tubes  LED TV  pool  internet  jacuzzi  \
# 0          0        0                1       0     0         0        0
#
#    kettle  sunny  open balcony  metal door  new wiring  laminatе flooring  \
# 0       0      1             1           1           1                  1
#
#    gym  cable TV  hardwood flooring  appliances  shower  washing machine  \
# 0    0         0                  0           1       0                1
#
#    elevator  kitchen tiled  playground  bathroom tiled  dinnerware  \
# 0         1              1           1               1           0
#
#    refrigerator  kitchen furniture  natural gas  intercom  air conditioner  \
# 0             1                  1            1         0                1
#
#    Wi-Fi  persistent water  built-in wardrobes  exclusive design  electricity  \
# 0      0                 1                   1                 0            1
#
#    expandable  furnished
# 0           0          1

# %%
feature_importance(bnakaran_dummy, "price")
# Out:
#                feature  importance
# 0                 area  0.47649584
# 4             latitude  0.20712687
# 25            cable TV  0.12647117
# 31       kitchen tiled  0.02509292
# 14              LED TV  0.02483568
# 45          expandable  0.02429529
# 6            longitude  0.02131188
# 18              kettle  0.00974749
# 5          visit_count  0.00898662
# 16            internet  0.00889878
# 10         sec. worker  0.00801729
# 46           furnished  0.00783913
# 2                floor  0.00754328
# 11           sec. sys.  0.00466313
# 23   laminatе flooring  0.00455646
# 3              storeys  0.00384173
# 1                rooms  0.00363413
# 19               sunny  0.00359008
# 13     new water tubes  0.00339382
# 22          new wiring  0.00317249
# 26   hardwood flooring  0.00263304
# 37         natural gas  0.00204747
# 38            intercom  0.00200209
# 15                pool  0.00166584
# 7     heating flooring  0.00163397
# 20        open balcony  0.00146794
# 17             jacuzzi  0.00121012
# 27          appliances  0.00108142
# 32          playground  0.00044983
# 28              shower  0.00039135
# 36   kitchen furniture  0.00039021
# 42  built-in wardrobes  0.00034284
# 35        refrigerator  0.00025861
# 29     washing machine  0.00021558
# 39     air conditioner  0.00014638
# 43    exclusive design  0.00014234
# 12             bathtub  0.00014156
# 30            elevator  0.00011640
# 40               Wi-Fi  0.00009818
# 9      plastic windows  0.00004765
# 24                 gym  0.00000126
# 44         electricity  0.00000078
# 8                oriel  0.00000069
# 41    persistent water  0.00000038
# 34          dinnerware  0.00000000
# 33      bathroom tiled  0.00000000
# 21          metal door  0.00000000
